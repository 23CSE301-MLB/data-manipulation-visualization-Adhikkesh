# %% [markdown]
# **Enter your code for Exercise 1 in the following cells (add as many cell as you need)**
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv("./insurance.csv")

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df[df["age"] > 18]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1269 rows x 7 columns]

# %%
df["is_male"] = df["sex"] == "male"

# %%
df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df.groupby("region")["charges"].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
df.sort_values(by=["charges","bmi"],ascending=[True,True])
# Out:
#       age     sex     bmi  children smoker     region      charges  is_male
# 940    18    male  23.210         0     no  southeast   1121.87390     True
# 808    18    male  30.140         0     no  southeast   1131.50660     True
# 1244   18    male  33.330         0     no  southeast   1135.94070     True
# 663    18    male  33.660         0     no  southeast   1136.39940     True
# 22     18    male  34.100         0     no  southeast   1137.01100     True
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 819    33  female  35.530         0    yes  northwest  55135.40209    False
# 577    31  female  38.095         1    yes  northeast  58571.07448    False
# 1230   52    male  34.485         3    yes  northwest  60021.39897     True
# 1300   45    male  30.360         0    yes  southeast  62592.87309     True
# 543    54  female  47.410         0    yes  southeast  63770.42801    False
#
# [1338 rows x 8 columns]

# %%
df.dropna()
# Out:
#       age     sex     bmi  children smoker     region      charges  is_male
# 0      19  female  27.900         0    yes  southwest  16884.92400    False
# 1      18    male  33.770         1     no  southeast   1725.55230     True
# 2      28    male  33.000         3     no  southeast   4449.46200     True
# 3      33    male  22.705         0     no  northwest  21984.47061     True
# 4      32    male  28.880         0     no  northwest   3866.85520     True
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830     True
# 1334   18  female  31.920         0     no  northeast   2205.98080    False
# 1335   18  female  36.850         0     no  southeast   1629.83350    False
# 1336   21  female  25.800         0     no  southwest   2007.94500    False
# 1337   61  female  29.070         0    yes  northwest  29141.36030    False
#
# [1338 rows x 8 columns]

# %%
cleaned_df = df["charges"].fillna(df["charges"].mean())

# %%
cleaned_df.to_csv("new_insurance.csv",index=True)

# %% [markdown]
# **Enter your code for Exercise 2 in the following cells (add as many cell as you need)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./insurance.csv")

# %%
import matplotlib.pyplot as plt

sns.histplot(data=df,x="charges",kde=True,bins=20,hue="smoker")
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.barplot(x="smoker", y="charges", data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sns.boxplot(x="region", y="charges", data=df)
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.scatterplot(x="bmi", y="charges", hue="smoker", data=df)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lineplot(x="sex",y="charges",hue="region",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
num_df = df.select_dtypes(include=['number'])
sns.heatmap(num_df.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.pairplot(df[["age", "bmi", "charges", "region"]], hue="region")
